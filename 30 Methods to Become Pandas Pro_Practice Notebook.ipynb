# %% [markdown]
# ## Introduction
# The article writes about 30 methods in Pandas that you should master to become a pro. This notebook is for practice of all the methods and codes described in the article
#
# Article link - https://towardsdatascience.com/the-only-30-methods-you-should-master-to-become-a-pandas-pro-749795084bb2
#
# A self sourced dataset will be used for the practice session.
#
# Dataset link https://1drv.ms/u/s!AlUtDZfIP_m2utpqo59I3OzJJe5G3w?e=0KzZKc
#
# Soyinka Sowoolu
# 3rd May 2023

# %%
# Import the Pandas library
import pandas as pd

# %% [markdown]
# ### 1. Reading a CSV File
#
# `pd.read_csv()`

# %%
file = "D:\\OneDrive\\Documents\\PERSONAL\\PERSONAL DEVELOPMENT\\DATA SCIENCE\\SQL\\Datasets for Personal Projects\\UK Accident Data\\accident data.csv"

df = pd.read_csv(file)
df
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    05-06-2019  51.506187
# 1       200701BS65737           Serious    02-07-2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight    03-09-2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
# Confirm the data structure type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 2. Store a DataFrame to a CSV
#
# `pd.read_csv()`

# %%
df.to_csv('uk_accidents_pd.csv', index=False)

# %%
# Reload to confirm the save
accident_df = pd.read_csv('uk_accidents_pd.csv')
accident_df
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    05-06-2019  51.506187
# 1       200701BS65737           Serious    02-07-2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight    03-09-2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# ### 3-4 Creating a DataFrame
#
# `pd.DataFrame()`

# %%
# From a list of lists

data = [[1, 2, "A"],
       [3, 4, "B"]]

df = pd.DataFrame(data, 
                 columns=["col1", "col2", 'col3'])

df
# Out:
#    col1  col2 col3
# 0     1     2    A
# 1     3     4    B

# %%
# From a Dictionary

data = {'col1': [1, 2],
       'col2': [3, 4],
       'col3': ['A', 'B']}

df = pd.DataFrame(data=data)
df
# Out:
#    col1  col2 col3
# 0     1     3    A
# 1     2     4    B

# %% [markdown]
# ### 5. Shape of the
#
# `pd.shape`

# %%
# Shape is an attribute (argument) of the DataFrame method/class thus has no () attached to it
accident_df.shape
# Out:
# (660679, 14)

# %% [markdown]
# ### 6. Viewing Top N and Bottom N rows
#
# `pd.head()` and `pd.tail()`

# %%
# View top 5 rows
accident_df.head(5)
# Out:
#            Index Accident_Severity Accident Date   Latitude  \
# 0  200701BS64157           Serious    05-06-2019  51.506187
# 1  200701BS65737           Serious    02-07-2019  51.495029
# 2  200701BS66127           Serious    26-08-2019  51.517715
# 3  200701BS66128           Serious    16-08-2019  51.495478
# 4  200701BS66837            Slight    03-09-2019  51.488576
#
#               Light_Conditions           District Area  Longitude  \
# 0        Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                     Daylight  Kensington and Chelsea  -0.173647
# 2  Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                     Daylight  Kensington and Chelsea  -0.202731
# 4        Darkness - lights lit  Kensington and Chelsea  -0.192487
#
#    Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                     1                   2                     Dry
# ...

# %%
# View the bottom 3 rows
accident_df.tail(3)
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#               Light_Conditions District Area  Longitude  Number_of_Casualties  \
# 660676                Daylight      Highland  -3.862727                     1
# 660677  Darkness - no lighting      Highland  -3.823997                     1
# 660678                Daylight      Highland  -3.895673                     1
#
#         Number_of_Vehicles Road_Surface_Conditions           Road_Type  \
# 660676                   3            Frost or ice  Single carriageway
# 660677                   2             Wet or damp  Single carriageway
# 660678                   1             Wet or damp    Dual carriageway
#
#        Urban_or_Rural_Area     Weather_Conditions           Vehicle_Type
# ...

# %% [markdown]
# ### 7.Printing the Datatype of columns
#
# `pd.dtypes`

# %%
# Print the dtype which is an attribute so no ()
accident_df.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %% [markdown]
# ### 8. Modifying the Dataytype of a column
#
# `pd.astype()`

# %%
# Change the dtype for the col1 column
import numpy as np
df['col1'] = df['col1'].astype(np.int8)
df.dtypes
# Out:
# col1      int8
# col2     int64
# col3    object
# dtype: object

# %% [markdown]
# ### 8-9. Printing Descriptive info about the DataFrame
#
# `pd.info()` and `pd.describe()`

# %%
# Using the info() to get general information
accident_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
# Use describe() to get descriptive statistics info
accident_df.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000
